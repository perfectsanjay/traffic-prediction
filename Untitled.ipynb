# %% [markdown]
# # Traffic Prediction

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import tensorflow
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras import callbacks
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")

# %%
#Loading Data
data = pd.read_csv('traffic.csv')
data.sample(5)
# Out:
#                   DateTime  Junction  Vehicles           ID
# 29881  2015-11-30 01:00:00         3         2  20151130013
# 606    2015-11-26 06:00:00         1        11  20151126061
# 15550  2015-12-10 22:00:00         2        12  20151210222
# 31124  2016-01-20 20:00:00         3         6  20160120203
# 38653  2016-11-29 13:00:00         3        18  20161129133

# %%
#Data Exploration

# %%
data['DateTime'] = pd.to_datetime(data['DateTime'])
data = data.drop(['ID'], axis=1) #dropping IDs
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48120 entries, 0 to 48119
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  48120 non-null  datetime64[ns]
#  1   Junction  48120 non-null  int64
#  2   Vehicles  48120 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 1.1 MB

# %%
#df to be used for EDA
df=data.copy()
#let's plot the Timeseries
colors = ["#FFD4DB","#BBE7FE","#D3B5E5","#dfe2b6"]
plt.figure(figsize=(20,4),facecolor='#627D78')
Time_series=sns.lineplot(x=df['DateTime'],y='Vehicles',data=df,hue='Junction',palette=colors)
Time_series.set_title('Traffic On Junction Over Years')
Time_series.set_ylabel('Number of Vehicles')
Time_series.set_xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# #Noticeable information in the above plot:

# %% [markdown]
# - it can be seen here that the first junction is visibly having an upward trend.

# %% [markdown]
# - The data for the fourth junction is sparse starting only after 2017

# %% [markdown]
# - Seasonality is not evident from the above plot, So we must explore datetime composition to figure out more about it.

# %% [markdown]
# # Feature Enginneering

# %%
#Exploring more features
df['Year']= df['DateTime'].dt.year
df['Month']= df['DateTime'].dt.month
df['Date_no']= df['DateTime'].dt.day
df['Hour']= df['DateTime'].dt.hour
df['Day']= df.DateTime.dt.strftime('%A')
df.head()
# Out:
#              DateTime  Junction  Vehicles  Year  Month  Date_no  Hour     Day
# 0 2015-11-01 00:00:00         1        15  2015     11        1     0  Sunday
# 1 2015-11-01 01:00:00         1        13  2015     11        1     1  Sunday
# 2 2015-11-01 02:00:00         1        10  2015     11        1     2  Sunday
# 3 2015-11-01 03:00:00         1         7  2015     11        1     3  Sunday
# 4 2015-11-01 04:00:00         1         9  2015     11        1     4  Sunday

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Let's plot the Timeserie
new_features = ['Year','Month', 'Date_no', 'Hour','Day']

for i in new_features:
    plt.figure(figsize=(10,2),facecolor='#627D78')
    ax=sns.lineplot(x=df[i],y='Vehicles',data=df, hue='Junction', palette=colors)
    plt.legend(bbox_to_anchor=(1.05,1),loc=2, borderaxespad=0.)

# %% [markdown]
# #From the above plot following things can be concluded

# %% [markdown]
# -Yearly, there has been an upward trend for all junctions except for the fourth junction. As we already established above that the fourth junction has limited data and that don't span over a year.

# %% [markdown]
# -We can see that there is an influx in the first and second junctions around June. I presume this may be due to summer break and activities around the same.

# %% [markdown]
# -Monthly, throughout all the dates there is a good consistency in data.

# %% [markdown]
# -For a day, we can see that are peaks during morning and evening times and a  decline during night hours. This is as per expectation.

# %% [markdown]
# -For weekly patterns, Sundays enjoy smoother traffic as there are lesser
#  vehicles on roads. Whereas Monday to Friday the traffic is steady.

# %%
plt.figure(figsize=(12,5),facecolor='#627D78')
count = sns.countplot(data=df, x=df['Year'], hue='Junction',palette=colors)
count.set_title('Count Of Traffic On Junctions Over Years')
count.set_ylabel('Number of Vehicles')
count.set_xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# -The count plot shows that there is an increase in the number of vehicles between 2015 and 2016. However, it is inconclusive to say the same about 2017 as we have limited data for 2017 ie till the 7th month.

# %%
corrmat = df.corr()
plt.subplots(figsize=(10,10),facecolor='#627D78')
sns.heatmap(corrmat,cmap= 'Pastel2',annot=True,square=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=df, hue= 'Junction',palette=colors)

# %% [markdown]
# #Conclusion that I have come to draw after this EDA

# %% [markdown]
# - The span of data from all four junctions is not the same. Data provided for the fourth junction is limited to only 2017.

# %% [markdown]
# - The yearly trend for Junctions one, two and three have diffrent slopes.

# %% [markdown]
# - Junction number one has a more strong weekly seasonality in comparison to the other junctions.

# %% [markdown]
# #Data Transformation And Preprocessing

# %%
#Pivoting data from junction
df_J = data.pivot(columns='Junction', index='DateTime')
df_J.describe()
# Out:
#               Vehicles
# Junction             1             2             3            4
# count     14592.000000  14592.000000  14592.000000  4344.000000
# mean         45.052906     14.253221     13.694010     7.251611
# std          23.008345      7.401307     10.436005     3.521455
# min           5.000000      1.000000      1.000000     1.000000
# 25%          27.000000      9.000000      7.000000     5.000000
# 50%          40.000000     13.000000     11.000000     7.000000
# 75%          59.000000     17.000000     18.000000     9.000000
# max         156.000000     48.000000    180.000000    36.000000

# %%
#Creating new sets
df_1 = df_J[[('Vehicles', 1)]]
df_2 = df_J[[('Vehicles', 2)]]
df_3 = df_J[[('Vehicles', 3)]]
df_4 = df_J[[('Vehicles', 4)]]
df_4 = df_4.dropna() #Junction 4 has limited data only for a few months

#Dropping level one in dfs's index as it is a multi index data frame
list_dfs = [df_1, df_2, df_3, df_4]
for i in list_dfs:
    i.columns= i.columns.droplevel(level=1)
    
#Function to plot comparitive plots of dataframes
def Sub_Plots4(df_1, df_2,df_3,df_4,title):
    fig, axes = plt.subplots(4, 1, figsize=(15, 8),facecolor="#627D78", sharey=True)
    fig.suptitle(title)
    #J1
    pl_1=sns.lineplot(ax=axes[0],data=df_1,color=colors[0])
    #pl_1=plt.ylabel()
    axes[0].set(ylabel ="Junction 1")
    #J2
    pl_2=sns.lineplot(ax=axes[1],data=df_2,color=colors[1])
    axes[1].set(ylabel ="Junction 2")
    #J3
    pl_3=sns.lineplot(ax=axes[2],data=df_3,color=colors[2])
    axes[2].set(ylabel ="Junction 3")
    #J4
    pl_4=sns.lineplot(ax=axes[3],data=df_4,color=colors[3])
    axes[3].set(ylabel ="Junction 4")
    
    
#Plotting the dataframe to check for stationarity
Sub_Plots4(df_1.Vehicles, df_2.Vehicles,df_3.Vehicles,df_4.Vehicles,"Dataframes Before Transformation")

# %% [markdown]
# #Steps for transforming:

# %% [markdown]
# - Normalizing
# - Differencing

# %%
# Normalize Function
def Normalize(df,col):
    average = df[col].mean()
    stdev = df[col].std()
    df_normalized = (df[col] - average)/stdev
    df_normalized = df_normalized.to_frame()
    return df_normalized, average, stdev

# Differencing Function
def Difference(df,col, interval):
    diff = []
    for i in range(interval, len(df)):
        value = df[col][i] - df[col][i - interval]
        diff.append(value)
    return diff

# %% [markdown]
# In accordance with the above observations, Differencing to eliminate the seasonality should be performed as follows:

# %% [markdown]
# - For Junction one, I will be taking a difference of weekly values.
# - For junction two, The difference of consecutive days is a better choice
# - For Junctions three and four, the difference of the hourly values will serve the purpose.

# %%
#Normalizing and Differencing to make the series stationary
df_N1, av_j1, std_J1 = Normalize(df_1, 'Vehicles')
Diff_1 = Difference(df_N1, col= 'Vehicles', interval=(24*7)) #taking a week's diffrence
df_N1 = df_N1[24*7:]
df_N1.columns = ['Norm']
df_N1['Diff']= Diff_1

df_N2, av_J2, std_J2 = Normalize(df_2, "Vehicles")
Diff_2 = Difference(df_N2, col="Vehicles", interval=(24)) #taking a day's diffrence
df_N2 = df_N2[24:]
df_N2.columns = ["Norm"]
df_N2["Diff"]= Diff_2

df_N3, av_J3, std_J3 = Normalize(df_3, "Vehicles")
Diff_3 = Difference(df_N3, col="Vehicles", interval=1) #taking an hour's diffrence
df_N3 = df_N3[1:]
df_N3.columns = ["Norm"]
df_N3["Diff"]= Diff_3

df_N4, av_J4, std_J4 = Normalize(df_4, "Vehicles")
Diff_4 = Difference(df_N4, col="Vehicles", interval=1) #taking an hour's diffrence
df_N4 = df_N4[1:]
df_N4.columns = ["Norm"]
df_N4["Diff"]= Diff_4

# %% [markdown]
# #plots of Transformed Dataframe

# %%
Sub_Plots4(df_N1.Diff, df_N2.Diff,df_N3.Diff,df_N4.Diff,'Dataframes After Transformation')

# %% [markdown]
# The plots above seem linear. To ensure they are Stationary I will be performing an Augmented Dickey-Fuller test.

# %%
#Stationary Check for the time series Augmented Dickey Fuller test
def Stationary_check(df):
    check = adfuller(df.dropna())
    print(f"ADF Statistic: {check[0]}")
    print(f"p-value: {check[1]}")
    print("Critical Values:")
    for key, value in check[4].items():
        print('\t%s: %.3f' % (key, value))
    if check[0] > check[4]["1%"]:
        print("Time Series is Non-Stationary")
    else:
        print("Time Series is Stationary") 
  

#Checking if the series is stationary

List_df_ND = [ df_N1["Diff"], df_N2["Diff"], df_N3["Diff"], df_N4["Diff"]] 
print("Checking the transformed series for stationarity:")
for i in List_df_ND:
    print("\n")
    Stationary_check(i)
# Out:
# Checking the transformed series for stationarity:
#
#
# ADF Statistic: -15.265303390415504
# p-value: 4.798539876395756e-28
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -21.795891026940065
# p-value: 0.0
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -28.001759908832625
# p-value: 0.0
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -17.979092563052486
# p-value: 2.7787875325950227e-30
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary

# %% [markdown]
# Now that the data is stationary, preprocessing the data for the neural net by:

# %% [markdown]
# - Splitting the test train sets
# - Assigning X as features and y as target
# - Reshaping data for neural net

# %%
#Differencing created some NA values as we tool a weeks data int o consideration while difrencing
df_J1 = df_N1['Diff'].dropna()
df_J1 = df_J1.to_frame()

df_J2 = df_N2["Diff"].dropna()
df_J2 = df_J2.to_frame()

df_J3 = df_N3["Diff"].dropna()
df_J3 = df_J3.to_frame()

df_J4 = df_N4["Diff"].dropna()
df_J4 = df_J4.to_frame()


#Splitting the dataset
def Split_data(df):
    training_size = int(len(df)*0.90)
    data_len = len(df)
    train, test = df[0:training_size],df[training_size:data_len] 
    train, test = train.values.reshape(-1, 1), test.values.reshape(-1, 1)
    return train, test
#Splitting the training and test datasets 
J1_train, J1_test = Split_data(df_J1)
J2_train, J2_test = Split_data(df_J2)
J3_train, J3_test = Split_data(df_J3)
J4_train, J4_test = Split_data(df_J4)

#Target and Feature
def TnF(df):
    end_len = len(df)
    X = []
    y = []
    steps = 32
    for i in range(steps, end_len):
        X.append(df[i - steps:i, 0])
        y.append(df[i, 0])
    X, y = np.array(X), np.array(y)
    return X ,y

#fixing the shape of X_test and X_train
def FeatureFixShape(train, test):
    train = np.reshape(train, (train.shape[0], train.shape[1], 1))
    test = np.reshape(test, (test.shape[0],test.shape[1],1))
    return train, test

#Assigning features and target 
X_trainJ1, y_trainJ1 = TnF(J1_train)
X_testJ1, y_testJ1 = TnF(J1_test)
X_trainJ1, X_testJ1 = FeatureFixShape(X_trainJ1, X_testJ1)

X_trainJ2, y_trainJ2 = TnF(J2_train)
X_testJ2, y_testJ2 = TnF(J2_test)
X_trainJ2, X_testJ2 = FeatureFixShape(X_trainJ2, X_testJ2)

X_trainJ3, y_trainJ3 = TnF(J3_train)
X_testJ3, y_testJ3 = TnF(J3_test)
X_trainJ3, X_testJ3 = FeatureFixShape(X_trainJ3, X_testJ3)

X_trainJ4, y_trainJ4 = TnF(J4_train)
X_testJ4, y_testJ4 = TnF(J4_test)
X_trainJ4, X_testJ4 = FeatureFixShape(X_trainJ4, X_testJ4)

# %% [markdown]
# # Model Building

# %%
#Model for the prediction
def GRU_model(X_Train, y_Train, X_Test):
    early_stopping = callbacks.EarlyStopping(min_delta=0.001,patience=10, restore_best_weights=True) 
    #callback delta 0.01 may interrupt the learning, could eliminate this step, but meh!
    
    #The GRU model 
    model = Sequential()
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    #model.add(GRU(units=50, return_sequences=True,  input_shape=(X_Train.shape[1],1),activation='tanh'))
    #model.add(Dropout(0.2))
    model.add(GRU(units=50, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    #Compiling the model
    model.compile(optimizer=SGD(decay=1e-7, momentum=0.9),loss='mean_squared_error')
    model.fit(X_Train,y_Train, epochs=50, batch_size=150,callbacks=[early_stopping])
    pred_GRU= model.predict(X_Test)
    return pred_GRU

#To calculate the root mean squred error in predictions
def RMSE_Value(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))
    return rmse

#To plot the comparitive plot of targets and predictions
def PredictionsPlot(test,predicted,m):
    plt.figure(figsize=(12,5),facecolor="#627D78")
    plt.plot(test, color=colors[m],label="True Value",alpha=0.5 )
    plt.plot(predicted, color="#627D78",label="Predicted Values")
    plt.title("GRU Traffic Prediction Vs True values")
    plt.xlabel("DateTime")
    plt.ylabel("Number of Vehicles")
    plt.legend()
    plt.show()

# %% [markdown]
# #Fitting The Model

# %% [markdown]
# Now, I will be fitting the transformed training sets of four junctions to the model created and compare them to the transformed test sets.

# %%
#Predictions For First Junction
PredJ1 = GRU_model(X_trainJ1,y_trainJ1,X_testJ1)
# Out:
# Epoch 1/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0773WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 206ms/step - loss: 0.0773
# Epoch 2/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0661WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 21s 244ms/step - loss: 0.0661
# Epoch 3/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0644WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 21s 246ms/step - loss: 0.0644
# Epoch 4/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0630WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 21s 243ms/step - loss: 0.0630
# Epoch 5/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0615WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 22s 248ms/step - loss: 0.0615
# Epoch 6/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0599WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 22s 251ms/step - loss: 0.0599
# Epoch 7/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0586WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 21s 243ms/step - loss: 0.0586
# Epoch 8/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0579WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 21s 247ms/step - loss: 0.0579
# Epoch 9/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0567WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 23s 267ms/step - loss: 0.0567
# Epoch 10/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0571WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 26s 294ms/step - loss: 0.0571
# Epoch 11/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0567WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 28s 328ms/step - loss: 0.0567
# Epoch 12/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0554WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 367ms/step - loss: 0.0554
# Epoch 13/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0550WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 26s 295ms/step - loss: 0.0550
# Epoch 14/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0546WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 24s 275ms/step - loss: 0.0546
# Epoch 15/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0537WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 28s 319ms/step - loss: 0.0537
# Epoch 16/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0533WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 31s 357ms/step - loss: 0.0533
# Epoch 17/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0536WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 291ms/step - loss: 0.0536
# Epoch 18/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0527WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 27s 306ms/step - loss: 0.0527
# Epoch 19/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0519WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 24s 280ms/step - loss: 0.0519
# Epoch 20/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0523WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 24s 278ms/step - loss: 0.0523
# Epoch 21/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0516WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 24s 275ms/step - loss: 0.0516
# Epoch 22/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0511WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 24s 280ms/step - loss: 0.0511
# Epoch 23/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0513WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 283ms/step - loss: 0.0513
# Epoch 24/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0508WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 286ms/step - loss: 0.0508
# Epoch 25/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0507WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 24s 280ms/step - loss: 0.0507
# Epoch 26/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0509WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 24s 277ms/step - loss: 0.0509
# Epoch 27/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0505WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 24s 281ms/step - loss: 0.0505
# Epoch 28/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0503WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 288ms/step - loss: 0.0503
# Epoch 29/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0507WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 23s 268ms/step - loss: 0.0507
# Epoch 30/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0504WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 23s 263ms/step - loss: 0.0504
# Epoch 31/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0499WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 23s 267ms/step - loss: 0.0499
# Epoch 32/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0496WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 25s 283ms/step - loss: 0.0496
# Epoch 33/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0500WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 24s 282ms/step - loss: 0.0500
# Epoch 34/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0500WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 22s 257ms/step - loss: 0.0500
# Epoch 35/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0489WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 23s 260ms/step - loss: 0.0489
# Epoch 36/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0495WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 24s 272ms/step - loss: 0.0495
# Epoch 37/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0489WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 22s 257ms/step - loss: 0.0489
# Epoch 38/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0487WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 22s 258ms/step - loss: 0.0487
# Epoch 39/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0491WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 22s 258ms/step - loss: 0.0491
# Epoch 40/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0487WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 23s 263ms/step - loss: 0.0487
# Epoch 41/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0484WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 22s 250ms/step - loss: 0.0484
# Epoch 42/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0483WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 22s 249ms/step - loss: 0.0483
# Epoch 43/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0485WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 21s 244ms/step - loss: 0.0485
# Epoch 44/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0479WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 21s 242ms/step - loss: 0.0479
# Epoch 45/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0482WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 21s 245ms/step - loss: 0.0482
# Epoch 46/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0481WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 21s 243ms/step - loss: 0.0481
# Epoch 47/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0483WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 21s 245ms/step - loss: 0.0483
# Epoch 48/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0479WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 23s 260ms/step - loss: 0.0479
# Epoch 49/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0477WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 23s 262ms/step - loss: 0.0477
# Epoch 50/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0479WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 24s 273ms/step - loss: 0.0479

# %%
#Results for J1 
RMSE_J1=RMSE_Value(y_testJ1,PredJ1)
PredictionsPlot(y_testJ1,PredJ1,0)
# Out:
# The root mean squared error is 0.2467203091809264.

# %% [markdown]
# Fitting the second junction and plotting the predictions and testset

# %%
#Predictions For Second Junction
PredJ2 = GRU_model(X_trainJ2,y_trainJ2,X_testJ2)
# Out:
# Epoch 1/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2326WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 304ms/step - loss: 0.2326
# Epoch 2/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2055WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 302ms/step - loss: 0.2055
# Epoch 3/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1981WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 292ms/step - loss: 0.1981
# Epoch 4/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1963WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 291ms/step - loss: 0.1963
# Epoch 5/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1935WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 293ms/step - loss: 0.1935
# Epoch 6/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1916WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 294ms/step - loss: 0.1916
# Epoch 7/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1897WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 293ms/step - loss: 0.1897
# Epoch 8/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1905WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 294ms/step - loss: 0.1905
# Epoch 9/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1888WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 28s 316ms/step - loss: 0.1888
# Epoch 10/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1899WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 28s 313ms/step - loss: 0.1899
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1869WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 28s 314ms/step - loss: 0.1869
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1869WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 28s 316ms/step - loss: 0.1869
# Epoch 13/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1881WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 28s 321ms/step - loss: 0.1881
# Epoch 14/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1878WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 330ms/step - loss: 0.1878
# Epoch 15/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1865WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 332ms/step - loss: 0.1865
# Epoch 16/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1864WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 303ms/step - loss: 0.1864
# Epoch 17/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1868WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 301ms/step - loss: 0.1868
# Epoch 18/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1880WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 301ms/step - loss: 0.1880
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1850WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 303ms/step - loss: 0.1850
# Epoch 20/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1854WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 298ms/step - loss: 0.1854
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1844WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 298ms/step - loss: 0.1844
# Epoch 22/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1856WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 28s 324ms/step - loss: 0.1856
# Epoch 23/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1848WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 325ms/step - loss: 0.1848
# Epoch 24/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1849WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 326ms/step - loss: 0.1849
# Epoch 25/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1831WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 297ms/step - loss: 0.1831
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1849WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 300ms/step - loss: 0.1849
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1848WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 297ms/step - loss: 0.1848
# Epoch 28/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1835WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 28s 316ms/step - loss: 0.1835
# Epoch 29/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1840WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 327ms/step - loss: 0.1840
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1835WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 28s 315ms/step - loss: 0.1835
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1852WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 28s 316ms/step - loss: 0.1852
# Epoch 32/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1829WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 28s 315ms/step - loss: 0.1829
# Epoch 33/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1828WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 299ms/step - loss: 0.1828
# Epoch 34/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1822WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 301ms/step - loss: 0.1822
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1828WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 299ms/step - loss: 0.1828
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1827WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 301ms/step - loss: 0.1827
# Epoch 37/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1816WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 298ms/step - loss: 0.1816
# Epoch 38/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1834WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 300ms/step - loss: 0.1834
# Epoch 39/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1817WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 335ms/step - loss: 0.1817
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1817WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 340ms/step - loss: 0.1817
# Epoch 41/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1819WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 29s 330ms/step - loss: 0.1819
# Epoch 42/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1816WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 31s 349ms/step - loss: 0.1816
# Epoch 43/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1803WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 30s 345ms/step - loss: 0.1803
# Epoch 44/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1828WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 300ms/step - loss: 0.1828
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1827WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 305ms/step - loss: 0.1827
# Epoch 46/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1822WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 298ms/step - loss: 0.1822
# Epoch 47/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1823WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 301ms/step - loss: 0.1823
# Epoch 48/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1814WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 301ms/step - loss: 0.1814
# Epoch 49/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 26s 298ms/step - loss: 0.1812
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1820WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 27s 302ms/step - loss: 0.1820

# %%
#Results for J2
RMSE_J2=RMSE_Value(y_testJ2,PredJ2)
PredictionsPlot(y_testJ2,PredJ2,1)
# Out:
# The root mean squared error is 0.5536867897833919.

# %% [markdown]
# Fitting the third junction and plotting the predictions and testset

# %%
#Predictions For Third Junction
PredJ3 = GRU_model(X_trainJ3,y_trainJ3,X_testJ3)
# Out:
# Epoch 1/50
# 88/88 [==============================] - ETA: 0s - loss: 0.3014WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 39s 371ms/step - loss: 0.3014
# Epoch 2/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2953WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 384ms/step - loss: 0.2953
# Epoch 3/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2903WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 372ms/step - loss: 0.2903
# Epoch 4/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2909WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 32s 366ms/step - loss: 0.2909
# Epoch 5/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2897WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 32s 365ms/step - loss: 0.2897
# Epoch 6/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2875WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 32s 368ms/step - loss: 0.2875
# Epoch 7/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2888WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 32s 367ms/step - loss: 0.2888
# Epoch 8/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2892WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 387ms/step - loss: 0.2892
# Epoch 9/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2876WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 36s 414ms/step - loss: 0.2876
# Epoch 10/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2885WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.2885
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2858WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 383ms/step - loss: 0.2858
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2866WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 390ms/step - loss: 0.2866
# Epoch 13/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2853WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 391ms/step - loss: 0.2853
# Epoch 14/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2833WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 371ms/step - loss: 0.2833
# Epoch 15/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2800WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 372ms/step - loss: 0.2800
# Epoch 16/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2811WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 372ms/step - loss: 0.2811
# Epoch 17/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2795WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 373ms/step - loss: 0.2795
# Epoch 18/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2759WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 381ms/step - loss: 0.2759
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2766WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.2766
# Epoch 20/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2755WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 36s 411ms/step - loss: 0.2755
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2775WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 39s 439ms/step - loss: 0.2775
# Epoch 22/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2817WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 35s 395ms/step - loss: 0.2817
# Epoch 23/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2757WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 37s 426ms/step - loss: 0.2757
# Epoch 24/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2750WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 35s 394ms/step - loss: 0.2750
# Epoch 25/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2726WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 381ms/step - loss: 0.2726
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2705WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 372ms/step - loss: 0.2705
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2727WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 35s 403ms/step - loss: 0.2727
# Epoch 28/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2705WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.2705
# Epoch 29/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2704WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 380ms/step - loss: 0.2704
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2690WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 35s 393ms/step - loss: 0.2690
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2703WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 35s 396ms/step - loss: 0.2703
# Epoch 32/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2698WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 35s 394ms/step - loss: 0.2698
# Epoch 33/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2684WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 380ms/step - loss: 0.2684
# Epoch 34/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2713WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 36s 404ms/step - loss: 0.2713
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2677WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 35s 402ms/step - loss: 0.2677
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2689WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 37s 425ms/step - loss: 0.2689
# Epoch 37/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2672WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 35s 400ms/step - loss: 0.2672
# Epoch 38/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2651WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 35s 403ms/step - loss: 0.2651
# Epoch 39/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2663WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 35s 399ms/step - loss: 0.2663
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2643WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 383ms/step - loss: 0.2643
# Epoch 41/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2667WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 384ms/step - loss: 0.2667
# Epoch 42/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2663WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 383ms/step - loss: 0.2663
# Epoch 43/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2648WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 383ms/step - loss: 0.2648
# Epoch 44/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2646WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 389ms/step - loss: 0.2646
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2661WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 382ms/step - loss: 0.2661
# Epoch 46/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2667WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 35s 402ms/step - loss: 0.2667
# Epoch 47/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2647WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 36s 411ms/step - loss: 0.2647
# Epoch 48/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2632WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 384ms/step - loss: 0.2632
# Epoch 49/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2644WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 35s 396ms/step - loss: 0.2644
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2630WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 35s 393ms/step - loss: 0.2630

# %%
#Results for J3
RMSE_J3=RMSE_Value(y_testJ3,PredJ3)
PredictionsPlot(y_testJ3,PredJ3,2)
# Out:
# The root mean squared error is 0.606228699302845.

# %% [markdown]
# Fitting the fourth junction and plotting the predictions and testset

# %%
#Predictions For Forth Junction
PredJ4 = GRU_model(X_trainJ4,y_trainJ4,X_testJ4)
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6920WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 17s 362ms/step - loss: 0.6920
# Epoch 2/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6913WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 337ms/step - loss: 0.6913
# Epoch 3/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6968WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 375ms/step - loss: 0.6968
# Epoch 4/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6903WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 381ms/step - loss: 0.6903
# Epoch 5/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6858WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 363ms/step - loss: 0.6858
# Epoch 6/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6820WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 363ms/step - loss: 0.6820
# Epoch 7/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6836WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 354ms/step - loss: 0.6836
# Epoch 8/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6788WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 367ms/step - loss: 0.6788
# Epoch 9/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6865WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 359ms/step - loss: 0.6865
# Epoch 10/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6798WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 352ms/step - loss: 0.6798
# Epoch 11/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6781WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 366ms/step - loss: 0.6781
# Epoch 12/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6746WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 351ms/step - loss: 0.6746
# Epoch 13/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6777WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 359ms/step - loss: 0.6777
# Epoch 14/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6828WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 364ms/step - loss: 0.6828
# Epoch 15/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6784WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 363ms/step - loss: 0.6784
# Epoch 16/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6750WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 365ms/step - loss: 0.6750
# Epoch 17/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6729WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 366ms/step - loss: 0.6729
# Epoch 18/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6726WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 376ms/step - loss: 0.6726
# Epoch 19/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6695WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 385ms/step - loss: 0.6695
# Epoch 20/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6713WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 394ms/step - loss: 0.6713
# Epoch 21/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6693WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 371ms/step - loss: 0.6693
# Epoch 22/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6685WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 358ms/step - loss: 0.6685
# Epoch 23/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6737WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 367ms/step - loss: 0.6737
# Epoch 24/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6676WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 356ms/step - loss: 0.6676
# Epoch 25/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6623WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 362ms/step - loss: 0.6623
# Epoch 26/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6687WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 365ms/step - loss: 0.6687
# Epoch 27/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6613WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 358ms/step - loss: 0.6613
# Epoch 28/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6562WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 367ms/step - loss: 0.6562
# Epoch 29/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6642WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 352ms/step - loss: 0.6642
# Epoch 30/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6541WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 364ms/step - loss: 0.6541
# Epoch 31/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6430WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 359ms/step - loss: 0.6430
# Epoch 32/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6419WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 354ms/step - loss: 0.6419
# Epoch 33/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6400WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 364ms/step - loss: 0.6400
# Epoch 34/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6295WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 354ms/step - loss: 0.6295
# Epoch 35/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6373WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 364ms/step - loss: 0.6373
# Epoch 36/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6194WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 359ms/step - loss: 0.6194
# Epoch 37/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6171WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 372ms/step - loss: 0.6171
# Epoch 38/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6119WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 367ms/step - loss: 0.6119
# Epoch 39/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6139WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 378ms/step - loss: 0.6139
# Epoch 40/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5850WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 11s 407ms/step - loss: 0.5850
# Epoch 41/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5905WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 13s 499ms/step - loss: 0.5905
# Epoch 42/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5801WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 12s 447ms/step - loss: 0.5801
# Epoch 43/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5724WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 11s 412ms/step - loss: 0.5724
# Epoch 44/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5653WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 11s 439ms/step - loss: 0.5653
# Epoch 45/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5492WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 397ms/step - loss: 0.5492
# Epoch 46/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5373WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 382ms/step - loss: 0.5373
# Epoch 47/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5470WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 382ms/step - loss: 0.5470
# Epoch 48/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5418WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 359ms/step - loss: 0.5418
# Epoch 49/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5547WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 9s 364ms/step - loss: 0.5547
# Epoch 50/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5360WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 382ms/step - loss: 0.5360

# %%
#Results for J4
RMSE_J4=RMSE_Value(y_testJ4,PredJ4)
PredictionsPlot(y_testJ4,PredJ4,3)
# Out:
# The root mean squared error is 1.008827892307345.
